# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisGuzman128/UIII-Act-4-diccionarios-utilizando-funciones-infografia-en-chatGPT-supervisor/blob/main/UIII_Act_4_diccionarios_utilizando_funciones_%2B_infografia_en_chatGPT_supervisor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Axel Guzman NL = 23
# ## Fecha 13/05/2026
# ## supervisor

# %%
# Diccionario vacío
diccionario_supervisor = {}

# --------------------------------------------------
# Función agregar supervisor
def agregar_supervisor():

    clave = input("Ingresa la clave del supervisor: ")

    nombre = input("Ingresa el nombre del supervisor: ")

    linea = input("Ingresa la línea de producción: ")

    empleados = input("Ingresa empleados bajo mando: ")

    incidencias = input("Ingresa reporte de incidencias: ")

    turno = input("Ingresa turno de trabajo: ")

    calidad = input("Ingresa indicador de calidad: ")

    planta = input("Ingresa planta: ")

    diccionario_supervisor[clave] = {
        "Nombre": nombre,
        "Linea": linea,
        "Empleados": empleados,
        "Incidencias": incidencias,
        "Turno": turno,
        "Calidad": calidad,
        "Planta": planta
    }

    print("Supervisor agregado correctamente.")

# --------------------------------------------------
# Función listar supervisores
def listar_supervisores():

    print("\n===================== TABLA DE SUPERVISORES =====================")

    print("{:<15} {:<20} {:<20} {:<15} {:<25} {:<15} {:<12} {:<18}".format(
        "CLAVE",
        "NOMBRE",
        "LINEA",
        "EMPLEADOS",
        "INCIDENCIAS",
        "TURNO",
        "CALIDAD",
        "PLANTA"
    ))

    print("-" * 150)

    for clave, valor in diccionario_supervisor.items():

        print("{:<15} {:<20} {:<20} {:<15} {:<25} {:<15} {:<12} {:<18}".format(
            clave,
            valor["Nombre"],
            valor["Linea"],
            valor["Empleados"],
            valor["Incidencias"],
            valor["Turno"],
            valor["Calidad"],
            valor["Planta"]
        ))

# --------------------------------------------------
# Función buscar supervisor
def buscar_supervisor():

    clave = input("Ingresa la clave del supervisor a buscar: ")

    if clave in diccionario_supervisor:

        print("\nSupervisor encontrado")
        print("--------------------------------------------------")

        for key, value in diccionario_supervisor[clave].items():

            print(key, ":", value)

    else:

        print("Supervisor no encontrado.")

# --------------------------------------------------
# Función borrar supervisor
def borrar_supervisor():

    clave = input("Ingresa la clave del supervisor a borrar: ")

    if clave in diccionario_supervisor:

        del diccionario_supervisor[clave]

        print("Supervisor eliminado correctamente.")

    else:

        print("Supervisor no encontrado.")

# --------------------------------------------------
# Función actualizar supervisor
def actualizar_supervisor():

    clave = input("Ingresa la clave del supervisor a actualizar: ")

    if clave in diccionario_supervisor:

        nombre = input("Nuevo nombre: ")

        linea = input("Nueva línea de producción: ")

        empleados = input("Nuevos empleados bajo mando: ")

        incidencias = input("Nuevo reporte de incidencias: ")

        turno = input("Nuevo turno de trabajo: ")

        calidad = input("Nuevo indicador de calidad: ")

        planta = input("Nueva planta: ")

        diccionario_supervisor[clave] = {
            "Nombre": nombre,
            "Linea": linea,
            "Empleados": empleados,
            "Incidencias": incidencias,
            "Turno": turno,
            "Calidad": calidad,
            "Planta": planta
        }

        print("Supervisor actualizado correctamente.")

    else:

        print("Supervisor no encontrado.")

# --------------------------------------------------
# Menú principal
while True:

    print("\n=========== MENU SUPERVISOR ===========")
    print("1. Agregar supervisor en diccionario")
    print("2. Listar diccionarios de supervisor")
    print("3. Buscar supervisor en diccionario")
    print("4. Borrar supervisor en diccionario")
    print("5. Actualizar supervisor en diccionario")
    print("6. Salir")

    opcion = input("Selecciona una opción: ")

    if opcion == "1":

        agregar_supervisor()

        listar_supervisores()

    elif opcion == "2":

        listar_supervisores()

    elif opcion == "3":

        buscar_supervisor()

        listar_supervisores()

    elif opcion == "4":

        borrar_supervisor()

        listar_supervisores()

    elif opcion == "5":

        actualizar_supervisor()

        listar_supervisores()

    elif opcion == "6":

        print("Saliendo del sistema...")
        break

    else:

        print("Opción inválida.")
# Out:
# =========== MENU SUPERVISOR ===========
# 1. Agregar supervisor en diccionario
# 2. Listar diccionarios de supervisor
# 3. Buscar supervisor en diccionario
# 4. Borrar supervisor en diccionario
# 5. Actualizar supervisor en diccionario
# 6. Salir
# Selecciona una opción: 1
# Ingresa la clave del supervisor: SUP01
# Ingresa el nombre del supervisor: Marco López
# Ingresa la línea de producción: Ensamblaje
# Ingresa empleados bajo mando: 15
# Ingresa reporte de incidencias: 2 fallas eléctricas
# Ingresa turno de trabajo: Matutino
# Ingresa indicador de calidad: 95%
# Ingresa planta: Planta Norte
# Supervisor agregado correctamente.
#
# ===================== TABLA DE SUPERVISORES =====================
# CLAVE           NOMBRE               LINEA                EMPLEADOS       INCIDENCIAS               TURNO           CALIDAD      PLANTA
# ...

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/LuisGuzman128/UIII-Act-4-diccionarios-utilizando-funciones-infografia-en-chatGPT-supervisor/refs/heads/main/infografia.png)
